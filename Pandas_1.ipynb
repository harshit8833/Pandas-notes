# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/survey_results_public.csv")

# %%
df.head(5) #top 5
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail(5) #bottom 5
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 80813       81317          I am a developer by profession      Yes
# 80814       81318          I am a developer by profession       No
# 80815       81319  I am a student who is learning to code      Yes
# 80816       81320          I am a developer by profession       No
# 80817       81321          I am a developer by profession       No
#
#                                              OpenSourcer  \
# 80813                            Less than once per year
# 80814  Less than once a month but more than once per ...
# 80815                                              Never
# 80816                                              Never
# 80817                                              Never
#
#                                               OpenSource          Employment  \
# 80813  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df.shape
# Out:
# (80818, 85)

# %%
df #cropped df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 80813       81317                     I am a developer by profession      Yes
# 80814       81318                     I am a developer by profession       No
# 80815       81319             I am a student who is learning to code      Yes
# 80816       81320                     I am a developer by profession       No
# 80817       81321                     I am a developer by profession       No
#
# ...

# %%
pd.set_option('display.max_columns', 85) #display 85 colm instead of ....
pd.set_option('display.max_rows', 85) #display 85 row instead of ....

# %%
df #check
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 80813       81317                     I am a developer by profession      Yes
# 80814       81318                     I am a developer by profession       No
# 80815       81319             I am a student who is learning to code      Yes
# 80816       81320                     I am a developer by profession       No
# 80817       81321                     I am a developer by profession       No
#
# ...

# %%
df.info() #info about data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80818 entries, 0 to 80817
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              80818 non-null  int64
#  1   MainBranch              80818 non-null  object
#  2   Hobbyist                80818 non-null  object
#  3   OpenSourcer             80818 non-null  object
#  4   OpenSource              79005 non-null  object
#  5   Employment              79332 non-null  object
#  6   Country                 80818 non-null  object
#  7   Student                 79256 non-null  object
#  8   EdLevel                 78700 non-null  object
#  9   UndergradMajor          68937 non-null  object
#  10  EduOther                76793 non-null  object
#  11  OrgSize                 65486 non-null  object
#  12  DevType                 74185 non-null  object
#  13  YearsCode               80113 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('/content/survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.10/dist-packages/pandas/__init__.py'>
